# %% [markdown]
# ## Python challenges
#
# This notebook includes a series of challenges to test your Python coding skills. If you get stuck, try googling for answers. If you don't understand *why* a particular answer works, try searching for the answer to that question. Revisit old tutorials from this class as needed, and finally, turn to the course chatroom for help. Best of luck.

# %%
# required software
# conda install numpy pandas toyplot requests -c conda-forge

# %%
import requests
import numpy as np
import pandas as pd
import toyplot

# %% [markdown]
# ### Challenge 1:
# Execute the code cell below to see an example of how it works.
# Use markdown in the cell after the code-block to describe the function `random_words_api`. Try to be descriptive about what each step of code in this function does, and why it works.

# %%
def random_words_api(nwords=10):
    "no docstring"
    URL = "https://random-word-api.herokuapp.com/word"
    response = requests.get(url=URL, params={"number": nwords})
    return response.json()

# demonstration
random_words_api(5)
# Out:
# ['solute', 'sown', 'insecurenesses', 'maltreating', 'jeroboams']

# %% [markdown]
# **Description:**<br>
# This code block is designed to retrive a certain number of random words from `random-word-api`.<br>
# The variable `URL` defines the URL of the API.<br>
# `response` stores the raw data retrived from the API, while variable `nwords` taken from the parameter defines the number of items that will be retrived, and the default was set to 10.<br>
# `return response.json()` returns the data in json format.

# %% [markdown]
# ### Challenge 2:
# Use the `random_words_api` function to get 50 random words and store the result as a variable. Write a function that takes the list of words as input and returns a dictionary with the longest word as the key and the length of the longest word as a value. If there is a tie in the length of words then have it return additional words as keys with their lengths as values.

# %%
def longest_word():
    LIST = random_words_api(50)
    dic = {}
    for words in LIST:
        if dic == {}:
            dic[words]=len(words)
        else:
            if list(dic.values())[0] > len(words):
                pass
            elif list(dic.values())[0] < len(words):
                dic.clear()
                dic[words]=len(words)
            else:
                dic[words]=len(words)
    return dic
longest_word()
# Out:
# {'easygoingnesses': 15}

# %% [markdown]
# ### Challenge 3:
# Write a function to take the list of words as input and trim all words to be at most 5 characters in length, and return as a list.

# %%
def random_dwarf_api():
    LIST = random_words_api(50)
    LIST_2=[]
    for words in LIST:
        words=words[0:5]
        LIST_2.append(words)
    return LIST_2
random_dwarf_api()[:10]
# Out:
# ['somat',
#  'benzi',
#  'unpeg',
#  'leach',
#  'kitte',
#  'hemod',
#  'kidvi',
#  'phila',
#  'reins',
#  'choan']

# %% [markdown]
# ### Challenge 4:
# Write a function to take a list of words as input and to count the occurrence of all letters in every word and return as a dictionary mapping letters to integers., e.g., {'a': 10, 'b': 3, 'c': 5, ...}.

# %%
import string
def random_frequency_api():
    LIST = random_words_api(50)
    counter={}
    for n in string.ascii_lowercase:
        counter[n]=0
    for words in LIST:
        for cha in words:
                counter[cha] += 1
    return counter
random_frequency_api()
# Out:
# {'a': 27,
#  'b': 10,
#  'c': 19,
#  'd': 8,
#  'e': 54,
#  'f': 10,
#  'g': 20,
#  'h': 9,
#  'i': 40,
#  'j': 0,
#  'k': 3,
#  'l': 24,
#  'm': 11,
#  'n': 20,
#  'o': 29,
#  'p': 7,
#  'q': 0,
#  'r': 39,
#  's': 37,
#  't': 28,
#  'u': 14,
#  'v': 3,
#  'w': 4,
#  'x': 2,
#  'y': 8,
#  'z': 2}

# %% [markdown]
# ### Challenge 5:
# Use [toyplot](https://toyplot.readthedocs.io/en/stable/tutorial.html) to create a barplot of the occurrences of each letter in your dictionary from the previous challenge. This will represent a histogram of the letters. Play with the size and color of the figure to try to make it look nice.

# %%
counter = random_frequency_api()
x = list(counter.keys())
y = list(counter.values())
color=toyplot.color.rgb(0.5,0.5,0.5)
canvas= toyplot.Canvas(width=400, height=300)
axes=canvas.cartesian(label="frequencies of each characters", xlabel="character", ylabel="frequency")
mark=axes.bars(y,color=color,title=y)
axes.x.ticks.locator = toyplot.locator.Explicit(labels=x)
# Out:
# <div class="toyplot" id="te50867c79d864179be86243812ad907b" style="text-align:center"><svg class="toyplot-canvas-Canvas" xmlns:toyplot="http://www.sandia.gov/toyplot" xmlns:xlink="http://www.w3.org/1999/xlink" xmlns="http://www.w3.org/2000/svg" width="400.0px" height="300.0px" viewBox="0 0 400.0 300.0" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;border-color:#292724;border-style:none;border-width:1.0;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" id="t76b496f9fe5b4ccc8272c6366122bec9"><g class="toyplot-coordinates-Cartesian" id="tbd4e6056d77243d0ae6515122f8a8b48"><clipPath id="t8b8f941ac0994a1abd0511b0986d6a78"><rect x="40.0" y="40.0" width="320.0" height="220.0"></rect></clipPath><g clip-path="url(#t8b8f941ac0994a1abd0511b0986d6a78)"><g class="toyplot-mark-BarMagnitudes" style="stroke:rgb(100%,100%,100%);stroke-opacity:1.0;stroke-width:1.0" id="tf783e42b2e064f23bd0276e8804eef8e"><g class="toyplot-Series"><rect class="toyplot-Datum" x="50.0" y="81.37254901960785" width="11.53846153846154" height="168.62745098039215" style="fill:rgb(50%,50%,50%);fill-opacity:1.0;opacity:1.0;stroke:rgb(100%,100%,100%);stroke-opacity:1.0;stroke-width:1.0"><title>43</title></rect><rect class="toyplot-Datum" x="61.53846153846154" y="222.54901960784315" width="11.53846153846154" height="27.45098039215685" style="fill:rgb(50%,50%,50%);fill-opacity:1.0;opacity:1.0;stroke:rgb(100%,100%,100%);stroke-opacity:1.0;stroke-width:1.0"><title>7</title></rect><rect class="toyplot-Datum" x="73.07692307692308" y="183.33333333333334" width="11.538461538461533" height="66.66666666666666" style="fill:rgb(50%,50%,50%);fill-opacity:1.0;opacity:1.0;stroke:rgb(100%,100%,100%);stroke-opacity:1.0;stroke-width:1.0"><title>17</title></rect><rect class="toyplot-Datum" x="84.61538461538461" y="195.09803921568627" width="11.538461538461547" height="54.90196078431373" style="fill:rgb(50%,50%,50%);fill-opacity:1.0;opacity:1.0;stroke:rgb(100%,100%,100%);stroke-opacity:1.0;stroke-width:1.0"><title>14</title></rect><rect class="toyplot-Datum" x="96.15384615384616" y="81.37254901960785" width="11.538461538461533" height="168.62745098039215" style="fill:rgb(50%,50%,50%);fill-opacity:1.0;opacity:1.0;stroke:rgb(100%,100%,100%);stroke-opacity:1.0;stroke-width:1.0"><title>43</title></rect><rect class="toyplot-Datum" x="107.6923076923077" y="210.78431372549022" width="11.538461538461533" height="39.21568627450978" style="fill:rgb(50%,50%,50%);fill-opacity:1.0;opacity:1.0;stroke:rgb(100%,100%,100%);stroke-opacity:1.0;stroke-width:1.0"><title>10</title></rect><rect class="toyplot-Datum" x="119.23076923076923" y="218.62745098039215" width="11.538461538461547" height="31.372549019607845" style="fill:rgb(50%,50%,50%);fill-opacity:1.0;opacity:1.0;stroke:rgb(100%,100%,100%);stroke-opacity:1.0;stroke-width:1.0"><title>8</title></rect><rect class="toyplot-Datum" x="130.76923076923077" y="206.8627450980392" width="11.538461538461547" height="43.1372549019608" style="fill:rgb(50%,50%,50%);fill-opacity:1.0;opacity:1.0;stroke:rgb(100%,100%,100%);stroke-opacity:1.0;stroke-width:1.0"><title>11</title></rect><rect class="toyplot-Datum" x="142.30769230769232" y="50.0" width="11.538461538461519" height="200.0" style="fill:rgb(50%,50%,50%);fill-opacity:1.0;opacity:1.0;stroke:rgb(100%,100%,100%);stroke-opacity:1.0;stroke-width:1.0"><title>51</title></rect><rect class="toyplot-Datum" x="153.84615384615384" y="250.0" width="11.538461538461547" height="0.0" style="fill:rgb(50%,50%,50%);fill-opacity:1.0;opacity:1.0;stroke:rgb(100%,100%,100%);stroke-opacity:1.0;stroke-width:1.0"><title>0</title></rect><rect class="toyplot-Datum" x="165.3846153846154" y="234.31372549019608" width="11.538461538461519" height="15.686274509803923" style="fill:rgb(50%,50%,50%);fill-opacity:1.0;opacity:1.0;stroke:rgb(100%,100%,100%);stroke-opacity:1.0;stroke-width:1.0"><title>4</title></rect><rec ...

# %% [markdown]
# ### Challenge 6:
# Using numpy create a new variable called `arr` with 1000 random samples from a normal distribution. Use the numpy `.histogram` function to bin these values into 20 bins, and then plot the histogram using a barplot from toyplot. Color the bars of the histogram orange.

# %%
from numpy import random
import toyplot.color
arr=random.standard_normal(1000)
his,boader=np.histogram(arr,bins=20)
canvas = toyplot.Canvas(width=400, height=300)
axes = canvas.cartesian(label="histogram of a random sampling", xlabel="bins", ylabel="frequency")
mark = axes.bars(his,color='orange')
# Out:
# <div class="toyplot" id="t21425089c94d41e2bd50747971d72db9" style="text-align:center"><svg class="toyplot-canvas-Canvas" xmlns:toyplot="http://www.sandia.gov/toyplot" xmlns:xlink="http://www.w3.org/1999/xlink" xmlns="http://www.w3.org/2000/svg" width="400.0px" height="300.0px" viewBox="0 0 400.0 300.0" preserveAspectRatio="xMidYMid meet" style="background-color:transparent;border-color:#292724;border-style:none;border-width:1.0;fill:rgb(16.1%,15.3%,14.1%);fill-opacity:1.0;font-family:Helvetica;font-size:12px;opacity:1.0;stroke:rgb(16.1%,15.3%,14.1%);stroke-opacity:1.0;stroke-width:1.0" id="t882f7f5d828d450eaeae22c9b4d3145a"><g class="toyplot-coordinates-Cartesian" id="t4f990bd772fa40d5a887f70860151733"><clipPath id="t32d8c23137a04d41809720d6a0176c7c"><rect x="40.0" y="40.0" width="320.0" height="220.0"></rect></clipPath><g clip-path="url(#t32d8c23137a04d41809720d6a0176c7c)"><g class="toyplot-mark-BarMagnitudes" style="stroke:rgb(100%,100%,100%);stroke-opacity:1.0;stroke-width:1.0" id="t55ee923921464640b0faaee79f8ba00c"><g class="toyplot-Series"><rect class="toyplot-Datum" x="50.0" y="246.15384615384613" width="14.63414634146342" height="3.846153846153868" style="fill:rgb(100%,64.7%,0%);fill-opacity:1.0;opacity:1.0;stroke:rgb(100%,100%,100%);stroke-opacity:1.0;stroke-width:1.0"></rect><rect class="toyplot-Datum" x="64.63414634146342" y="234.6153846153846" width="14.63414634146342" height="15.384615384615387" style="fill:rgb(100%,64.7%,0%);fill-opacity:1.0;opacity:1.0;stroke:rgb(100%,100%,100%);stroke-opacity:1.0;stroke-width:1.0"></rect><rect class="toyplot-Datum" x="79.26829268292684" y="213.46153846153845" width="14.634146341463406" height="36.53846153846155" style="fill:rgb(100%,64.7%,0%);fill-opacity:1.0;opacity:1.0;stroke:rgb(100%,100%,100%);stroke-opacity:1.0;stroke-width:1.0"></rect><rect class="toyplot-Datum" x="93.90243902439025" y="186.53846153846155" width="14.63414634146342" height="63.46153846153845" style="fill:rgb(100%,64.7%,0%);fill-opacity:1.0;opacity:1.0;stroke:rgb(100%,100%,100%);stroke-opacity:1.0;stroke-width:1.0"></rect><rect class="toyplot-Datum" x="108.53658536585367" y="182.69230769230768" width="14.634146341463392" height="67.30769230769232" style="fill:rgb(100%,64.7%,0%);fill-opacity:1.0;opacity:1.0;stroke:rgb(100%,100%,100%);stroke-opacity:1.0;stroke-width:1.0"></rect><rect class="toyplot-Datum" x="123.17073170731706" y="150.0" width="14.634146341463435" height="100.0" style="fill:rgb(100%,64.7%,0%);fill-opacity:1.0;opacity:1.0;stroke:rgb(100%,100%,100%);stroke-opacity:1.0;stroke-width:1.0"></rect><rect class="toyplot-Datum" x="137.8048780487805" y="111.53846153846155" width="14.634146341463406" height="138.46153846153845" style="fill:rgb(100%,64.7%,0%);fill-opacity:1.0;opacity:1.0;stroke:rgb(100%,100%,100%);stroke-opacity:1.0;stroke-width:1.0"></rect><rect class="toyplot-Datum" x="152.4390243902439" y="50.0" width="14.634146341463435" height="200.0" style="fill:rgb(100%,64.7%,0%);fill-opacity:1.0;opacity:1.0;stroke:rgb(100%,100%,100%);stroke-opacity:1.0;stroke-width:1.0"></rect><rect class="toyplot-Datum" x="167.07317073170734" y="78.84615384615385" width="14.634146341463406" height="171.15384615384613" style="fill:rgb(100%,64.7%,0%);fill-opacity:1.0;opacity:1.0;stroke:rgb(100%,100%,100%);stroke-opacity:1.0;stroke-width:1.0"></rect><rect class="toyplot-Datum" x="181.70731707317074" y="69.23076923076923" width="14.634146341463378" height="180.76923076923077" style="fill:rgb(100%,64.7%,0%);fill-opacity:1.0;opacity:1.0;stroke:rgb(100%,100%,100%);stroke-opacity:1.0;stroke-width:1.0"></rect><rect class="toyplot-Datum" x="196.34146341463412" y="55.769230769230774" width="14.634146341463435" height="194.23076923076923" style="fill:rgb(100%,64.7%,0%);fill-opacity:1.0;opacity:1.0;stroke:rgb(100%,100%,100%);stroke-opacity:1.0;stroke-width:1.0"></rect><rect class="toyplot-Datum" x="210.97560975609755" y="75.0" width="14.634146341463435" height="175.0" style="fill:rgb(100%,64.7%,0%);fill-opacity:1.0;opacity:1.0 ...

# %% [markdown]
# ### Challenge 7:
# Write a `while` statement to continue running code in a loop until a condition is met, and then call `break` to end the loop. Inside of the loop, randomly draw a single value from a uniform distribution between 0 and 100. If the value is less than 25 and greater than 22 then break the loop, otherwise, continue the loop until a value meeting this condition is sampled. Use a variable to keep track of how many iterations of the loop are run, and print this value after calling `break`.

# %%
def looper():
    counter = int(1)
    while 1:
        draw=np.random.rand()*100
        if draw >22 and draw <25:
            break
        else:
            pass
        counter +=1
    return counter
looper()
# Out:
# 41

# %% [markdown]
# ### Challenge 8:
# Use pandas to load a CSV file from https://eaton-lab.org/data/iris-data-dirty.csv and save as a dataframe. Add custom names to the columns in the dataframe, based on the type of values in them (e.g., numeric versus strings). You can come up with any column names you want for these.

# %%
URL='https://eaton-lab.org/data/iris-data-dirty.csv'
df=pd.read_csv(URL,header=None).rename(columns={0:'f1',1:'f2',2:'f3',3:'f4',4:'str'})
df
# Out:
#       f1   f2   f3   f4             str
# 0    5.1  3.5  1.4  0.2     Iris-setosa
# 1    4.9  3.0  1.4  0.2     Iris-setosa
# 2    4.7  3.2  1.3  0.2     Iris-setosa
# 3    4.6  3.1  1.5  0.2     Iris-setosa
# 4    5.0  3.6  1.4  0.2     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  6.7  3.0  5.2  2.3  Iris-virginica
# 146  6.3  2.5  5.0  1.9  Iris-virginica
# 147  6.5  3.0  5.2  2.0  Iris-virginica
# 148  6.2  3.4  5.4  2.3  Iris-virginica
# 149  5.9  3.0  5.1  1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# ### Challenge 9:
# Calculate the mean value of the data in the left-most column for all data where the right-most column matches the value "Iris-setosa".

# %%
mean_f1=df[df.str=="Iris-setosa"].f1.mean()
mean_f1
# Out:
# 5.010204081632653

# %% [markdown]
# ### Challenge 10:
# Create a copy of your iris data dataframe and name it `df2`. Sort the rows of this dataframe based on the values in the first (leftmost) column so that the lowest values are first, and the highest values at the bottom. After sorting, reset the index of the dataframe so that the index is once again ordered. Once you get this to work, try to rewrite it in a simpler form by chaining multiple function calls together to accomplish the goal in one line, by calling code that looks a bit like this, but with the correct function calls: `df.function().function().function()`

# %%
df2=df.sort_values(by='f1').reset_index(drop=1)
df2
# Out:
#       f1   f2   f3   f4             str
# 0    4.3  3.0  1.1  0.1     Iris-setosa
# 1    4.4  3.2  1.3  0.2     Iris-setosa
# 2    4.4  3.0  1.3  0.2     Iris-setosa
# 3    4.4  2.9  1.4  0.2     Iris-setosa
# 4    4.5  2.3  1.3  0.3     Iris-setosa
# ..   ...  ...  ...  ...             ...
# 145  7.7  2.8  6.7  2.0  Iris-virginica
# 146  7.7  2.6  6.9  2.3  Iris-virginica
# 147  7.7  3.8  6.7  2.2  Iris-virginica
# 148  7.7  3.0  6.1  2.3  Iris-virginica
# 149  7.9  3.8  6.4  2.0  Iris-virginica
#
# [150 rows x 5 columns]

# %% [markdown]
# ### Challenge 11:
# Write a function that uses string formatting (curly braces) to create a [mad lib](https://en.wikipedia.org/wiki/Mad_Libs) containing at least 4 words that will be filled in. The returned object of your function should be a string where the missing words are filled by randomly sampled words from the `random_words_api()` function. The sentence or paragraph of your mad lib can be anything you wish, be creative.

# %%
def mad_lib_filler():
    word_list=random_words_api(4)
    n1=word_list[0]
    n2=word_list[1]
    n3=word_list[2]
    n4=word_list[3]
    return f"""MANY YEARS LATER as he faced the ({n1}), Colonel Aureliano Buendía was to remember that distant afternoon when \
his father took him to discover ({n2}). At that time ({n3}) was a village of twenty adobe houses, built on the bank of a \
river of clear water that ran along a bed of polished stones, which were white and enormous, like ({n4})."""
mad_lib_filler()
# Out:
# 'MANY YEARS LATER as he faced the (sprinklers), Colonel Aureliano Buendía was to remember that distant afternoon when his father took him to discover (burnable). At that time (finches) was a village of twenty adobe houses, built on the bank of a river of clear water that ran along a bed of polished stones, which were white and enormous, like (deuces).'

# %% [markdown]
# <div class="alert alert-success">
# After completing all challenges in this notebook, save and download the .ipynb file to your computer. Move the file to your hack-program repo and put it in a folder called notebooks. Add/stage this file and folder and commit the change, and push to GitHub. The assignment is due by end of day on 3/7/2021.
# </div>
